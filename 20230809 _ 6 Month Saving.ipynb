# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import numpy as np
import os

import openpyxl

# Max column
pd.set_option('display.max_columns', None)

# %%
#Location of file
os.getcwd()
# Out:
# 'C:\\Users\\shaikh.kamran\\ProjectPurchase'

# %% [markdown]
# #### Load Data

# %% [markdown]
# * List of purchaser

# %%
#ID file location
ID_file = pd.read_excel("D:/Shaikh_Desktop_Mydoc/Desktop/Automation Projects/20230727_Savings_Report_Commercial/Data/ID2.xlsx")

# Extract the IDs from the ID file
IDs = ID_file['Name']

# %% [markdown]
# * Monthly data

# %%
file_path = "D:/Shaikh_Desktop_Mydoc/Desktop/Automation Projects/20230727_Savings_Report_Commercial/Data/PurchaseHistoryReport_July23.xls"

# %%
# Define the data types for specific columns
data_types = {
    'Order Date': 'datetime64',
    'Item Code': str,
    'POReference': str,
    'Supplier Id': str
}

# Load the data from Excel file, skipping the first 5 rows, and applying data types
MonthlyData = pd.read_excel(file_path, skiprows=range(0, 5), dtype=data_types)

# Print the DataFrame
display(MonthlyData.head(5))
display(MonthlyData.info())
display(MonthlyData.shape)
# Out:
#    Unnamed: 0        Business  Unnamed: 2 Supplier Id  \
# 0         NaN  ACI Foods Ltd.         NaN    01230531
# 1         NaN  ACI Foods Ltd.         NaN    01230257
# 2         NaN  ACI Foods Ltd.         NaN    01180011
# 3         NaN  ACI Foods Ltd.         NaN    01180011
# 4         NaN  ACI Foods Ltd.         NaN    01180011
#
#                Supplier Name  Unnamed: 5  Unnamed: 6     Country  Unnamed: 8  \
# 0                  Dallas Ad         NaN         NaN  Bangladesh         NaN
# 1  Ad Pro Communications Ltd         NaN         NaN  Bangladesh         NaN
# 2      Asiatic Mindshare Ltd         NaN         NaN         NaN         NaN
# 3      Asiatic Mindshare Ltd         NaN         NaN         NaN         NaN
# 4      Asiatic Mindshare Ltd         NaN         NaN         NaN         NaN
#
#   Currency POReference  Unnamed: 11 Order Date Order Type Category  \
# 0      BDT  2307000082          NaN 2023-07-03  Biz Promo       PI
# 1      BDT  2307000311          NaN 2023-07-05  Biz Promo       PI
# 2      BDT  2307000312          NaN 2023-07-05  Biz Promo       PI
# 3      BDT  2307000312          NaN 2023-07-05  Biz Promo       PI
# 4      BDT  2307000313          NaN 2023-07-05  Biz Promo       PI
#
#     Item Code                   Item Name    Unit  POQuantity     PORate  \
# 0  5000003899                    Branding    Unit         1.0  1800000.0
# 1  5000003899                    Branding    Unit         1.0   120000.0
# 2  5000004576           Agency Commission    Each         1.0    10000.0
# 3  5000010679        Digital Media Buying   Month         1.0   200000.0
# 4  5000049271  Digital Media Retainership  Months         1.0   150000.0
#
#       Amount  Advance            Create By         Create Date
# 0  1800000.0      0.0  Anik Kumar Devnath  2023-07-03 08:32:53
# 1   120000.0      0.0  Anik Kumar Devnath  2023-07-05 12:17:41
# 2    10000.0      0.0     Md. Jashim Uddin 2023-07-05 12:07:21
# 3   200000.0      0.0     Md. Jashim Uddin 2023-07-05 12:07:21
# 4   150000.0      0.0     Md. Jashim Uddin 2023-07-05 12:03:34
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6564 entries, 0 to 6563
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     0 non-null      float64
#  1   Business       6564 non-null   object
#  2   Unnamed: 2     0 non-null      float64
#  3   Supplier Id    6564 non-null   object
#  4   Supplier Name  6564 non-null   object
#  5   Unnamed: 5     0 non-null      float64
#  6   Unnamed: 6     0 non-null      float64
#  7   Country        6464 non-null   object
#  8   Unnamed: 8     0 non-null      float64
#  9   Currency       6564 non-null   object
#  10  POReference    6564 non-null   object
#  11  Unnamed: 11    0 non-null      float64
#  12  Order Date     6564 non-null   datetime64[ns]
#  13  Order Type     6564 non-null   object
#  14  Category       6564 non-null   object
#  15  Item Code      6564 non-null   object
#  16  Item Name      6564 non-null   object
#  17  Unit           6564 non-null   object
#  18  POQuantity     6564 non-null   float64
#  19  PORate         6564 non-null   float64
#  20  Amount         6564 non-null   float64
#  21  Advance        6564 non-null   float64
#  22  Create By      6564 non-null   object
#  23  Create Date    6564 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(10), object(12)
# memory usage: 1.2+ MB
# None
# (6564, 24)

# %%
MonthlyData.columns
# Out:
# Index(['Unnamed: 0', 'Business', 'Unnamed: 2', 'Supplier Id', 'Supplier Name',
#        'Unnamed: 5', 'Unnamed: 6', 'Country', 'Unnamed: 8', 'Currency',
#        'POReference', 'Unnamed: 11', 'Order Date', 'Order Type', 'Category',
#        'Item Code', 'Item Name', 'Unit', 'POQuantity', 'PORate', 'Amount',
#        'Advance', 'Create By', 'Create Date'],
#       dtype='object')

# %%
# Specify the columns you want to keep from the other file
columns_to_keep = ['Unnamed: 0', 'Business', 'Unnamed: 2', 'Supplier Id', 'Supplier Name',
       'Unnamed: 5', 'Unnamed: 6', 'Country', 'Unnamed: 8', 'Currency',
       'POReference', 'Unnamed: 11', 'Order Date', 'Order Type', 'Category',
       'Item Code', 'Item Name', 'Unit', 'POQuantity', 'PORate', 'Amount',
       'Advance', 'Create By', 'Create Date']

# %%
# Filter the other file based on the IDs and select the desired columns
MonthlyData_Commercial_only = MonthlyData[MonthlyData['Create By'].isin(IDs)][columns_to_keep]

MonthlyData_Commercial_only
display(MonthlyData_Commercial_only.shape)
# Out:
# (1505, 24)

# %%
MonthlyData['Business'].unique()
# Out:
# array(['ACI Foods Ltd.', 'ACI Salt', 'Animal Health', 'CB Core ',
#        'Hygiene', 'Pharma', 'ACI Agrolink Limited',
#        'ACI Crop Care (ACI Formulations Limited)', 'ACI Flour',
#        'ACI Motors Limited', 'ACI Premio Plastics', 'Aerosol',
#        'Electrical', 'Fertilizer', 'Field Crops', 'Foton', 'Paint',
#        'Premiaflex', 'Servier', 'Vegetables', 'Yamaha',
#        'ACI Animal Genetics', 'ACI Biotech Limited',
#        'ACI Chemicals Limited ', 'ACI CO-RO', 'ACI Consumer Electronics',
#        'ACI HealthCare Limited', 'AFL ', 'Agri Machineries',
#        'Common (Support Function)', 'Edible Oil', 'Rice', 'Vanish',
#        'Vegetables-EWS'], dtype=object)

# %% [markdown]
# ## Data cleaning and Data manipulation
#
# <p> Remove Order type 'Biz Promo', 'Contract Order' </p>
# <p> Remove Business ACI CO-RO </p>
# <p> <mark> Remove row if Category contains PI </mark> </p>
# <p> <mark> Remove 'FG' and 'RM' from Electrical </mark> </p>
# <p> Remove Colgate, Cevac, Freight, Colgate </p>
# <p> Remove Import items from 'Vegetables', 'Field Crops', 'Vegetables-EWS'</p>

# %%
##________________________________ the values to remove________________________________

values_to_remove_ordertype = ['Biz Promo', 'Contract Order']
values_to_remove_business = ['ACI CO-RO']
values_to_remove_Category = ['PI']

# Filter the DataFrame to remove rows where "Order Type" column contains specific values
df = MonthlyData_Commercial_only[~MonthlyData_Commercial_only['Order Type'].isin(values_to_remove_ordertype)]
df = df[~df['Business'].isin(values_to_remove_ordertype)]
df = df[~df['Item Name'].str.contains('Colgate', case=False)]
df = df[~df['Item Name'].str.contains('Cevac', case=False)]
df = df[~df['Item Name'].str.contains('Freight', case=False)]
df = df[~df['Supplier Name'].str.contains('Colgate', case=False)]
df = df[~df['Category'].isin(values_to_remove_Category)]



### Define the conditions for removing rows
business_to_exclude = ['Electrical']
category_to_exclude = ['FG', 'RM']

# Filter rows based on the specified conditions
df = df[~((df['Business'].isin(business_to_exclude)) & (df['Category'].isin(category_to_exclude)))]


### Define the conditions for removing rows
business_to_exclude2 = ['Vegetables', 'Field Crops', 'Vegetables-EWS']
category_to_exclude2 = ['Import']

# Filter rows based on the specified conditions
df = df[~((df['Business'].isin(business_to_exclude2)) & (df['Order Type'].isin(category_to_exclude2)))]







##________________________________ the values to rename________________________________

df.loc[(df['Order Type'] == 'Import') & (df['Currency'] == 'BDT'), 'Order Type'] = 'Native'    # Local LC to Local
df['Order Type'] = df['Order Type'].apply(lambda x: x.replace('Native', 'Local'))              # Native to Local


display(df.shape)




#Note
#The ~ operator negates the condition, so it selects rows where the
# Out:
# (1421, 24)

# %% [markdown]
# * Outlier detection

# %%
Local_Non_BDT1 = df.loc[(df['Order Type'] == 'Local') & (df['Currency'] != 'BDT')]
Local_Non_BDT2 = df.loc[(df['Order Type'] == 'Native')]
Import_BDT = df.loc[(df['Order Type'] == 'Import') & (df['Currency'] == 'BDT')]

# %%
duplicate_rows = df[df.duplicated(subset=['Currency','Item Code', 'POQuantity'], keep=False)]

# %% [markdown]
# ### Import Data from Another DataBase

# %%
# File Path for WAP

File_WAP = "D:/Shaikh_Desktop_Mydoc/Desktop/Automation Projects/20230727_Savings_Report_Commercial/Output_file/6M_Lastprice_WAP_AVRate.xlsx"

# %%
# Name of Sheets in WAP file

# Load the Excel file using openpyxl
workbook = openpyxl.load_workbook(File_WAP)

# Get the list of sheet names
sheet_names = workbook.sheetnames

# Print the list of sheet names
display(sheet_names)
# Out:
# ['July23', 'Dec22', 'Lastprice', 'WAP', 'AV_Rate']

# %% [markdown]
# * Average Rate

# %%
# Specify the sheet name from which you want to load data
AVRate_fy_22_23 = "AV_Rate" 

# Load data from the specified sheet
AVRate_ = pd.read_excel(File_WAP, sheet_name= AVRate_fy_22_23)

display(AVRate_.columns)
display(AVRate_.head(5))
display(AVRate_.shape)


# AVRate_.rename(columns={'PORate': 'AVRate'}, inplace=True)


display(AVRate_.columns)
display(AVRate_.head(5))
display(AVRate_.shape)




df = pd.merge(df, AVRate_, on=['Business', 'Item Code', 'Currency'], how='left')
display(df.head(5))
display(df.shape)
# Out:
# Index(['Business', 'Item Code', 'Currency', 'AVRate'], dtype='object')
#                Business   Item Code Currency   AVRate
# 0  ACI Agrolink Limited  0701000061      USD     2.74
# 1  ACI Agrolink Limited  5000001062      BDT  1750.00
# 2  ACI Agrolink Limited  5000002354      BDT   270.00
# 3  ACI Agrolink Limited  5000003502      BDT  5000.00
# 4  ACI Agrolink Limited  5000003503      BDT  6750.00
# (23577, 4)
# Index(['Business', 'Item Code', 'Currency', 'AVRate'], dtype='object')
#                Business   Item Code Currency   AVRate
# 0  ACI Agrolink Limited  0701000061      USD     2.74
# 1  ACI Agrolink Limited  5000001062      BDT  1750.00
# 2  ACI Agrolink Limited  5000002354      BDT   270.00
# 3  ACI Agrolink Limited  5000003502      BDT  5000.00
# 4  ACI Agrolink Limited  5000003503      BDT  6750.00
# (23577, 4)
#    Unnamed: 0                                  Business  Unnamed: 2  \
# 0         NaN                      ACI Agrolink Limited         NaN
# 1         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 2         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 3         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 4         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
#
#   Supplier Id                               Supplier Name  Unnamed: 5  \
# 0    01191150  Shandong Weifang Rainbow Chemical Co. Ltd.         NaN
# 1    01180791            Coromandel International Limited         NaN
# 2        NSCL                Ningbo Synagrochem Co., Ltd.         NaN
# 3    01160037             NINGBO SUNJOY BIOSCIENCE CO LTD         NaN
# 4          HC                        Huikwang Corporation         NaN
#
#    Unnamed: 6 Country  Unnamed: 8 Currency POReference  Unnamed: 11  \
# 0         NaN   China         NaN      USD  2307000770          NaN
# 1         NaN   India         NaN      USD  2307000286          NaN
# 2         NaN   China         NaN      USD  2307000287          NaN
# 3         NaN   China         NaN      USD  2307000285          NaN
# 4         NaN  Taiwan         NaN      USD  2307000306          NaN
#
#   Order Date Order Type Category   Item Code                      Item Name  \
# 0 2023-07-10     Import       RM  0701000061                  Prism 27.5 SC
# 1 2023-07-05     Import       RM  0701000088  Bondage 80 WP (Blue Mancozeb)
# 2 2023-07-05     Import       RM  0701000011        ACIPRID PLUS 95 SP BULK
# 3 2023-07-05     Import       RM  0701000021                Camamix 750 WP
# 4 2023-07-05     Import       RM     1002019                     Nuben Bulk
#
#   Unit  POQuantity  PORate    Amount  Advance             Create By  \
# 0  Ltr     48000.0    2.12  101760.0      0.0  Faisal Ahmed Tahasan
# 1   Kg     14000.0    2.70   37800.0      0.0  Faisal Ahmed Tahasan
# 2   KG      6000.0   19.40  116400.0      0.0  Faisal Ahmed Tahasan
# 3   Kg     25000.0    4.25  106250.0      0.0  Faisal Ahmed Tahasan
# 4   KG     30000.0    3.70  111000.0      0.0  Faisal Ahmed Tahasan
#
#           Create Date  AVRate
# 0 2023-07-10 15:42:27    2.74
# 1 2023-07-05 10:43:56     NaN
# 2 2023-07-05 10:48:39     NaN
# 3 2023-07-05 10:39:08     NaN
# 4 2023-07-05 12:02:15     NaN
# (1421, 25)

# %% [markdown]
# * WAP

# %%
# Specify the sheet name from which you want to load data
WAP_fy_22_23 = "WAP" 

# Load data from the specified sheet
WAP_ = pd.read_excel(File_WAP, sheet_name=WAP_fy_22_23)

display(WAP_.columns)
display(WAP_.head(5))
display(WAP_.shape)
# Out:
# Index(['Business', 'Item Code', 'Currency', 'WAP'], dtype='object')
#                Business   Item Code Currency      WAP
# 0  ACI Agrolink Limited  0701000061      USD     2.74
# 1  ACI Agrolink Limited  5000001062      BDT  1750.00
# 2  ACI Agrolink Limited  5000002354      BDT   270.00
# 3  ACI Agrolink Limited  5000003502      BDT  5000.00
# 4  ACI Agrolink Limited  5000003503      BDT  6750.00
# (23577, 4)

# %%
# left outer join


df_report = pd.merge(df, WAP_, on=['Business', 'Item Code', 'Currency'], how='left')
display(df_report.head(5))
display(df_report.shape)
# Out:
#    Unnamed: 0                                  Business  Unnamed: 2  \
# 0         NaN                      ACI Agrolink Limited         NaN
# 1         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 2         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 3         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 4         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
#
#   Supplier Id                               Supplier Name  Unnamed: 5  \
# 0    01191150  Shandong Weifang Rainbow Chemical Co. Ltd.         NaN
# 1    01180791            Coromandel International Limited         NaN
# 2        NSCL                Ningbo Synagrochem Co., Ltd.         NaN
# 3    01160037             NINGBO SUNJOY BIOSCIENCE CO LTD         NaN
# 4          HC                        Huikwang Corporation         NaN
#
#    Unnamed: 6 Country  Unnamed: 8 Currency POReference  Unnamed: 11  \
# 0         NaN   China         NaN      USD  2307000770          NaN
# 1         NaN   India         NaN      USD  2307000286          NaN
# 2         NaN   China         NaN      USD  2307000287          NaN
# 3         NaN   China         NaN      USD  2307000285          NaN
# 4         NaN  Taiwan         NaN      USD  2307000306          NaN
#
#   Order Date Order Type Category   Item Code                      Item Name  \
# 0 2023-07-10     Import       RM  0701000061                  Prism 27.5 SC
# 1 2023-07-05     Import       RM  0701000088  Bondage 80 WP (Blue Mancozeb)
# 2 2023-07-05     Import       RM  0701000011        ACIPRID PLUS 95 SP BULK
# 3 2023-07-05     Import       RM  0701000021                Camamix 750 WP
# 4 2023-07-05     Import       RM     1002019                     Nuben Bulk
#
#   Unit  POQuantity  PORate    Amount  Advance             Create By  \
# 0  Ltr     48000.0    2.12  101760.0      0.0  Faisal Ahmed Tahasan
# 1   Kg     14000.0    2.70   37800.0      0.0  Faisal Ahmed Tahasan
# 2   KG      6000.0   19.40  116400.0      0.0  Faisal Ahmed Tahasan
# 3   Kg     25000.0    4.25  106250.0      0.0  Faisal Ahmed Tahasan
# 4   KG     30000.0    3.70  111000.0      0.0  Faisal Ahmed Tahasan
#
#           Create Date  AVRate   WAP
# 0 2023-07-10 15:42:27    2.74  2.74
# 1 2023-07-05 10:43:56     NaN   NaN
# 2 2023-07-05 10:48:39     NaN   NaN
# 3 2023-07-05 10:39:08     NaN   NaN
# 4 2023-07-05 12:02:15     NaN   NaN
# (1421, 26)

# %% [markdown]
# * June or previous

# %%
# Specify the sheet name from which you want to load data
July_or_previous = "July23" 

# Load data from the specified sheet
July__ = pd.read_excel(File_WAP, sheet_name=July_or_previous)

display(July__.columns)
display(July__.head(5))
display(July__.shape)



# Columns for June or previous 

columns_to_keep_June = ['Business','Currency','Item Code', 'PORate']
July__ = July__[columns_to_keep_June]

July__.rename(columns={'PORate': 'June or Previous price'}, inplace=True)

July__.columns
display(July__.head(5))
display(July__.info())
# Out:
# Index(['Unnamed: 0', 'Business', 'Column1', 'Supplier Id', 'Supplier Name',
#        'Column2', 'Column3', 'Country', 'Column4', 'Currency', 'POReference',
#        'Column5', 'Order Date', 'Order Type', 'Category', 'Item Code',
#        'Item Name', 'Unit', 'POQuantity', 'PORate', 'Amount', 'Advance',
#        'Create By', 'Create Date', 'Year', 'Month', 'YYYY-MMM'],
#       dtype='object')
#    Unnamed: 0             Business  Column1 Supplier Id  \
# 0         NaN               Pharma      NaN    01160887
# 1         NaN       ACI Foods Ltd.      NaN  PREMIAFLEX
# 2         NaN                 Rice      NaN    01170603
# 3         NaN  ACI Premio Plastics      NaN    01220443
# 4         NaN               Pharma      NaN        BPPL
#
#                               Supplier Name  Column2  Column3     Country  \
# 0  HPZ Strategic Printing And Packaging Ltd      NaN      NaN  Bangladesh
# 1               PREMIAFLEX PLASTICS LIMITED      NaN      NaN  Bangladesh
# 2                   M/S Zihad Nayan Traders      NaN      NaN  Bangladesh
# 3                        VIVA PRINTING PACK      NaN      NaN  Bangladesh
# 4                     Best Printers Limited      NaN      NaN  Bangladesh
#
#    Column4 Currency POReference  Column5 Order Date Order Type Category  \
# 0      NaN      BDT  2208000021      NaN 2022-07-31     Native       PM
# 1      NaN      BDT  2207001994      NaN 2022-07-31     Native       PM
# 2      NaN      BDT  2207002045      NaN 2022-07-31     Native       RM
# 3      NaN      BDT  2207001972      NaN 2022-07-31     Native       PM
# 4      NaN      BDT  2208000017      NaN 2022-07-31     Native       PM
#
#     Item Code                                  Item Name Unit  POQuantity  \
# 0    040673/C                  XCEL 665 ER TABLET CARTON  PCS     12000.0
# 1     PML0679  Fun140gm Chanachur Wrapper ( Hot & Spicy)   Kg      1000.0
# 2  1801000006                              Paddy BR - 29   kg     19500.0
# 3  3102000742              Big Corner for Platinum WD-5D  PCS     12000.0
# 4    030452/A                  PALIMAX ER TABLET LEAFLET  PCS     10000.0
#
#     PORate    Amount  Advance              Create By         Create Date  \
# 0    3.920   47040.0      0.0  Masudur Rahman Bhuyan 2022-07-31 17:20:04
# 1  440.000  440000.0      0.0  Mohammad Russel Dhali 2022-07-31 11:05:09
# 2   31.375  611812.5      0.0          Sumsut Tabrej 2022-07-31 16:10:12
# 3   25.000  300000.0      0.0   Md. Faridul Huq Khan 2022-07-31 10:39:35
# 4    0.360    3600.0      0.0  Masudur Rahman Bhuyan 2022-07-31 17:02:51
#
#    Year Month   YYYY-MMM
# 0  2022  July  2022-July
# 1  2022  July  2022-July
# 2  2022  July  2022-July
# 3  2022  July  2022-July
# 4  2022  July  2022-July
# (45295, 27)
#               Business Currency   Item Code  June or Previous price
# 0               Pharma      BDT    040673/C                   3.920
# 1       ACI Foods Ltd.      BDT     PML0679                 440.000
# 2                 Rice      BDT  1801000006                  31.375
# 3  ACI Premio Plastics      BDT  3102000742                  25.000
# 4               Pharma      BDT    030452/A                   0.360
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45295 entries, 0 to 45294
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Business                45295 non-null  object
#  1   Currency                45295 non-null  object
#  2   Item Code               45295 non-null  object
#  3   June or Previous price  45295 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.4+ MB
# None

# %%
# left outer join


df_report = pd.merge(df_report, July__, on=['Business', 'Item Code', 'Currency'], how='left')
display(df_report.head(5))
display(df_report.shape)
# Out:
#    Unnamed: 0                                  Business  Unnamed: 2  \
# 0         NaN                      ACI Agrolink Limited         NaN
# 1         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 2         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 3         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 4         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
#
#   Supplier Id                               Supplier Name  Unnamed: 5  \
# 0    01191150  Shandong Weifang Rainbow Chemical Co. Ltd.         NaN
# 1    01180791            Coromandel International Limited         NaN
# 2        NSCL                Ningbo Synagrochem Co., Ltd.         NaN
# 3    01160037             NINGBO SUNJOY BIOSCIENCE CO LTD         NaN
# 4          HC                        Huikwang Corporation         NaN
#
#    Unnamed: 6 Country  Unnamed: 8 Currency POReference  Unnamed: 11  \
# 0         NaN   China         NaN      USD  2307000770          NaN
# 1         NaN   India         NaN      USD  2307000286          NaN
# 2         NaN   China         NaN      USD  2307000287          NaN
# 3         NaN   China         NaN      USD  2307000285          NaN
# 4         NaN  Taiwan         NaN      USD  2307000306          NaN
#
#   Order Date Order Type Category   Item Code                      Item Name  \
# 0 2023-07-10     Import       RM  0701000061                  Prism 27.5 SC
# 1 2023-07-05     Import       RM  0701000088  Bondage 80 WP (Blue Mancozeb)
# 2 2023-07-05     Import       RM  0701000011        ACIPRID PLUS 95 SP BULK
# 3 2023-07-05     Import       RM  0701000021                Camamix 750 WP
# 4 2023-07-05     Import       RM     1002019                     Nuben Bulk
#
#   Unit  POQuantity  PORate    Amount  Advance             Create By  \
# 0  Ltr     48000.0    2.12  101760.0      0.0  Faisal Ahmed Tahasan
# 1   Kg     14000.0    2.70   37800.0      0.0  Faisal Ahmed Tahasan
# 2   KG      6000.0   19.40  116400.0      0.0  Faisal Ahmed Tahasan
# 3   Kg     25000.0    4.25  106250.0      0.0  Faisal Ahmed Tahasan
# 4   KG     30000.0    3.70  111000.0      0.0  Faisal Ahmed Tahasan
#
#           Create Date  AVRate   WAP  June or Previous price
# 0 2023-07-10 15:42:27    2.74  2.74                    3.02
# 1 2023-07-05 10:43:56     NaN   NaN                    3.90
# 2 2023-07-05 10:48:39     NaN   NaN                   25.50
# 3 2023-07-05 10:39:08     NaN   NaN                    5.30
# 4 2023-07-05 12:02:15     NaN   NaN                    4.80
# (1421, 27)

# %% [markdown]
# * Last Price

# %%
data_types = {
    'Order Date': 'datetime64',
    'Item Code': str,
    'POReference': str,
    'Supplier Id': str
}




# Specify the sheet name from which you want to load data
Last_Price = "Lastprice" 

# Load data from the specified sheet
Last_Price_ = pd.read_excel(File_WAP, sheet_name= Last_Price, dtype = data_types)

display(Last_Price_.columns)
display(Last_Price_.head(5))
display(Last_Price_.shape)



# Columns for June or previous 

columns_to_keep_LP = ['Business','Currency','POReference','Item Code', 'Last_Price']
Last_Price__ = Last_Price_[columns_to_keep_LP]

# Last_Price__.rename(columns={'PORate': 'LastPrice'}, inplace=True)

Last_Price__.columns
display(Last_Price__.head(5))
display(Last_Price__.info())
# Out:
# Index(['Unnamed: 0', 'Business', 'Column1', 'Supplier Id', 'Supplier Name',
#        'Column2', 'Column3', 'Country', 'Column4', 'Currency', 'POReference',
#        'Column5', 'Order Date', 'Order Type', 'Category', 'Item Code',
#        'Item Name', 'Unit', 'POQuantity', 'PORate', 'Amount', 'Advance',
#        'Create By', 'Create Date', 'Year', 'Month', 'YYYY-MMM', 'Last_Price'],
#       dtype='object')
#    Unnamed: 0 Business  Column1 Supplier Id  \
# 0         NaN   Yamaha      NaN    01180765
# 1         NaN   Yamaha      NaN    01180765
# 2         NaN   Yamaha      NaN    01180765
# 3         NaN   Yamaha      NaN    01220252
# 4         NaN   Yamaha      NaN    01180765
#
#                               Supplier Name  Column2  Column3 Country  \
# 0           India Yamaha Motor Private Ltd.      NaN      NaN   India
# 1           India Yamaha Motor Private Ltd.      NaN      NaN   India
# 2           India Yamaha Motor Private Ltd.      NaN      NaN   India
# 3  HYUNDAI STEEL PIPE INDIA PRIVATE LIMITED      NaN      NaN   India
# 4           India Yamaha Motor Private Ltd.      NaN      NaN   India
#
#    Column4 Currency POReference  Column5 Order Date Order Type Category  \
# 0      NaN      USD  2307000074      NaN 2023-07-02     Import       SM
# 1      NaN      USD  2307000065      NaN 2023-07-02     Import       SM
# 2      NaN      USD  2307000072      NaN 2023-07-02     Import       SM
# 3      NaN      USD  2307000059      NaN 2023-07-02     Import       SM
# 4      NaN      USD  2307000066      NaN 2023-07-02     Import       SM
#
#     Item Code                                          Item Name Unit  \
# 0  2904000125                           OEM PARTS FOR MOTORCYCLE  PCS
# 1  2904000125                           OEM PARTS FOR MOTORCYCLE  PCS
# 2  2904000125                           OEM PARTS FOR MOTORCYCLE  PCS
# 3  2904000119  Tubes/Pipes for Motorcycle Manufacturing (Back...  PCS
# 4  2904000125                           OEM PARTS FOR MOTORCYCLE  PCS
#
#    POQuantity   PORate      Amount  Advance     Create By         Create Date  \
# 0     16800.0  7.12798  119750.064      0.0  Ayesha Akter 2023-07-02 16:42:59
# 1     19050.0  4.19816   79974.948      0.0  Ayesha Akter 2023-07-02 12:12:35
# 2    103600.0  0.88948   92150.128      0.0  Ayesha Akter 2023-07-02 16:37:08
# 3      1200.0  9.23000   11076.000      0.0  Ayesha Akter 2023-07-02 11:29:00
# 4     57600.0  0.71658   41275.008      0.0  Ayesha Akter 2023-07-02 12:23:19
#
#    Year Month   YYYY-MMM  Last_Price
# 0  2023  July  2023-July     0.88948
# 1  2023  July  2023-July     7.12798
# 2  2023  July  2023-July     4.19816
# 3  2023  July  2023-July     9.19833
# 4  2023  July  2023-July     0.88948
# (6564, 28)
#   Business Currency POReference   Item Code  Last_Price
# 0   Yamaha      USD  2307000074  2904000125     0.88948
# 1   Yamaha      USD  2307000065  2904000125     7.12798
# 2   Yamaha      USD  2307000072  2904000125     4.19816
# 3   Yamaha      USD  2307000059  2904000119     9.19833
# 4   Yamaha      USD  2307000066  2904000125     0.88948
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6564 entries, 0 to 6563
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Business     6564 non-null   object
#  1   Currency     6564 non-null   object
#  2   POReference  6564 non-null   object
#  3   Item Code    6564 non-null   object
#  4   Last_Price   4676 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 256.5+ KB
# None

# %%
# left outer join


df_report = pd.merge(df_report, Last_Price__, on=['POReference', 'Business', 'Item Code', 'Currency'], how='left')
display(df_report.head(5))
display(df_report.shape)
# Out:
#    Unnamed: 0                                  Business  Unnamed: 2  \
# 0         NaN                      ACI Agrolink Limited         NaN
# 1         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 2         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 3         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 4         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
#
#   Supplier Id                               Supplier Name  Unnamed: 5  \
# 0    01191150  Shandong Weifang Rainbow Chemical Co. Ltd.         NaN
# 1    01180791            Coromandel International Limited         NaN
# 2        NSCL                Ningbo Synagrochem Co., Ltd.         NaN
# 3    01160037             NINGBO SUNJOY BIOSCIENCE CO LTD         NaN
# 4          HC                        Huikwang Corporation         NaN
#
#    Unnamed: 6 Country  Unnamed: 8 Currency POReference  Unnamed: 11  \
# 0         NaN   China         NaN      USD  2307000770          NaN
# 1         NaN   India         NaN      USD  2307000286          NaN
# 2         NaN   China         NaN      USD  2307000287          NaN
# 3         NaN   China         NaN      USD  2307000285          NaN
# 4         NaN  Taiwan         NaN      USD  2307000306          NaN
#
#   Order Date Order Type Category   Item Code                      Item Name  \
# 0 2023-07-10     Import       RM  0701000061                  Prism 27.5 SC
# 1 2023-07-05     Import       RM  0701000088  Bondage 80 WP (Blue Mancozeb)
# 2 2023-07-05     Import       RM  0701000011        ACIPRID PLUS 95 SP BULK
# 3 2023-07-05     Import       RM  0701000021                Camamix 750 WP
# 4 2023-07-05     Import       RM     1002019                     Nuben Bulk
#
#   Unit  POQuantity  PORate    Amount  Advance             Create By  \
# 0  Ltr     48000.0    2.12  101760.0      0.0  Faisal Ahmed Tahasan
# 1   Kg     14000.0    2.70   37800.0      0.0  Faisal Ahmed Tahasan
# 2   KG      6000.0   19.40  116400.0      0.0  Faisal Ahmed Tahasan
# 3   Kg     25000.0    4.25  106250.0      0.0  Faisal Ahmed Tahasan
# 4   KG     30000.0    3.70  111000.0      0.0  Faisal Ahmed Tahasan
#
#           Create Date  AVRate   WAP  June or Previous price  Last_Price
# 0 2023-07-10 15:42:27    2.74  2.74                    3.02        2.74
# 1 2023-07-05 10:43:56     NaN   NaN                    3.90        3.90
# 2 2023-07-05 10:48:39     NaN   NaN                   25.50       25.50
# 3 2023-07-05 10:39:08     NaN   NaN                    5.30        5.30
# 4 2023-07-05 12:02:15     NaN   NaN                    4.80        4.80
# (1421, 28)

# %%
df_report_ = df_report.copy()

# %% [markdown]
# ### Analytics : 001

# %% [markdown]
# * Calculate variance (WAP vs Average Rate)

# %%
df_Analytics = df_report.copy()
display(df_Analytics.columns)
# Out:
# Index(['Unnamed: 0', 'Business', 'Unnamed: 2', 'Supplier Id', 'Supplier Name',
#        'Unnamed: 5', 'Unnamed: 6', 'Country', 'Unnamed: 8', 'Currency',
#        'POReference', 'Unnamed: 11', 'Order Date', 'Order Type', 'Category',
#        'Item Code', 'Item Name', 'Unit', 'POQuantity', 'PORate', 'Amount',
#        'Advance', 'Create By', 'Create Date', 'AVRate', 'WAP',
#        'June or Previous price', 'Last_Price'],
#       dtype='object')

# %%
columns_to_keep_Analytics = ['Business', 'Supplier Id', 'Supplier Name','Country', 'Currency','POReference', 'Order Date', 'Order Type', 'Category',
'Item Code', 'Item Name', 'Unit', 'POQuantity', 'PORate', 'Amount','Advance', 'Create By', 'Create Date', 'AVRate', 'WAP',
       'June or Previous price', 'Last_Price']
df_Analytics = df_Analytics[columns_to_keep_Analytics]

display(df_Analytics.head(5))
display(df_Analytics.shape)
display(df_Analytics.info())
# Out:
#                                    Business Supplier Id  \
# 0                      ACI Agrolink Limited    01191150
# 1  ACI Crop Care (ACI Formulations Limited)    01180791
# 2  ACI Crop Care (ACI Formulations Limited)        NSCL
# 3  ACI Crop Care (ACI Formulations Limited)    01160037
# 4  ACI Crop Care (ACI Formulations Limited)          HC
#
#                                 Supplier Name Country Currency POReference  \
# 0  Shandong Weifang Rainbow Chemical Co. Ltd.   China      USD  2307000770
# 1            Coromandel International Limited   India      USD  2307000286
# 2                Ningbo Synagrochem Co., Ltd.   China      USD  2307000287
# 3             NINGBO SUNJOY BIOSCIENCE CO LTD   China      USD  2307000285
# 4                        Huikwang Corporation  Taiwan      USD  2307000306
#
#   Order Date Order Type Category   Item Code                      Item Name  \
# 0 2023-07-10     Import       RM  0701000061                  Prism 27.5 SC
# 1 2023-07-05     Import       RM  0701000088  Bondage 80 WP (Blue Mancozeb)
# 2 2023-07-05     Import       RM  0701000011        ACIPRID PLUS 95 SP BULK
# 3 2023-07-05     Import       RM  0701000021                Camamix 750 WP
# 4 2023-07-05     Import       RM     1002019                     Nuben Bulk
#
#   Unit  POQuantity  PORate    Amount  Advance             Create By  \
# 0  Ltr     48000.0    2.12  101760.0      0.0  Faisal Ahmed Tahasan
# 1   Kg     14000.0    2.70   37800.0      0.0  Faisal Ahmed Tahasan
# 2   KG      6000.0   19.40  116400.0      0.0  Faisal Ahmed Tahasan
# 3   Kg     25000.0    4.25  106250.0      0.0  Faisal Ahmed Tahasan
# 4   KG     30000.0    3.70  111000.0      0.0  Faisal Ahmed Tahasan
#
#           Create Date  AVRate   WAP  June or Previous price  Last_Price
# 0 2023-07-10 15:42:27    2.74  2.74                    3.02        2.74
# 1 2023-07-05 10:43:56     NaN   NaN                    3.90        3.90
# 2 2023-07-05 10:48:39     NaN   NaN                   25.50       25.50
# 3 2023-07-05 10:39:08     NaN   NaN                    5.30        5.30
# 4 2023-07-05 12:02:15     NaN   NaN                    4.80        4.80
# (1421, 22)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1420
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Business                1421 non-null   object
#  1   Supplier Id             1421 non-null   object
#  2   Supplier Name           1421 non-null   object
#  3   Country                 1415 non-null   object
#  4   Currency                1421 non-null   object
#  5   POReference             1421 non-null   object
#  6   Order Date              1421 non-null   datetime64[ns]
#  7   Order Type              1421 non-null   object
#  8   Category                1421 non-null   object
#  9   Item Code               1421 non-null   object
#  10  Item Name               1421 non-null   object
#  11  Unit                    1421 non-null   object
#  12  POQuantity              1421 non-null   float64
#  13  PORate                  1421 non-null   float64
#  14  Amount                  1421 non-null   float64
#  15  Advance                 1421 non-null   float64
#  16  Create By               1421 non-null   object
#  17  Create Date             1421 non-null   datetime64[ns]
#  18  AVRate                  1124 non-null   float64
#  19  WAP                     1124 non-null   float64
#  20  June or Previous price  1020 non-null   float64
#  21  Last_Price              1277 non-null   float64
# dtypes: datetime64[ns](2), float64(8), object(12)
# memory usage: 255.3+ KB
# None

# %%
# Calculate the variance between AVRate and WAP
df_Analytics['Difference'] = (df_Analytics['AVRate'] - df_Analytics['WAP'])
df_Analytics['Variance_P'] = ((df_Analytics['AVRate'] - df_Analytics['WAP'])/df_Analytics['AVRate'])*100

# Create a separate DataFrame for high variance cases
high_variance_df = df_Analytics[df_Analytics['Variance_P'].abs() >5]

# Print the DataFrames
display("Original DataFrame:")
display(df_Analytics)
display("\nHigh Variance DataFrame:")
display(high_variance_df)
display(high_variance_df.shape)
# Out:
# 'Original DataFrame:'
#                                       Business Supplier Id  \
# 0                         ACI Agrolink Limited    01191150
# 1     ACI Crop Care (ACI Formulations Limited)    01180791
# 2     ACI Crop Care (ACI Formulations Limited)        NSCL
# 3     ACI Crop Care (ACI Formulations Limited)    01160037
# 4     ACI Crop Care (ACI Formulations Limited)          HC
# ...                                        ...         ...
# 1416                            Vegetables-EWS    01200503
# 1417                            Vegetables-EWS    01200503
# 1418                            Vegetables-EWS    01200503
# 1419                            Vegetables-EWS    01200503
# 1420                            Vegetables-EWS    01200503
#
#                                    Supplier Name     Country Currency  \
# 0     Shandong Weifang Rainbow Chemical Co. Ltd.       China      USD
# 1               Coromandel International Limited       India      USD
# 2                   Ningbo Synagrochem Co., Ltd.       China      USD
# 3                NINGBO SUNJOY BIOSCIENCE CO LTD       China      USD
# 4                           Huikwang Corporation      Taiwan      USD
# ...                                          ...         ...      ...
# 1416   East West Seed Bangladesh Private Limited  Bangladesh      BDT
# 1417   East West Seed Bangladesh Private Limited  Bangladesh      BDT
# 1418   East West Seed Bangladesh Private Limited  Bangladesh      BDT
# 51   188.0      0.0  Krishno Gopal Saha 2023-07-20 08:48:15  0.379000
#
#          WAP  June or Previous price  Last_Price  Difference  Variance_P
# 30  0.277222                 0.21604       0.300    0.023111    7.695154
# 31  0.314000                 0.28670       0.460    0.036500   10.413695
# 40  0.220909                     NaN       0.310    0.158091   41.712641
# 42  0.284500                     NaN       0.472    0.067500   19.176136
# 51  0.220909                     NaN       0.162    0.158091   41.712641
# (45, 24)

# %% [markdown]
# ### Load data: From historical DB

# %%
# Folder path containing the files
pathSpecified = "D:/Shaikh_Desktop_Mydoc/Desktop/Automation Projects/20220622 PriceMirror/MMS2018JanTo2023Jun"  # Replace with the actual folder path

# Using listdir() function  
listOfFileNames = os.listdir(pathSpecified)


# Print the name of all files in directory  
print("Following is the list of names of all the files present in the specified directory: ")  
# Create an empty DataFrame to store the combined data
combined_data = pd.DataFrame()
print(listOfFileNames)



# Create an empty DataFrame to store the combined data
combined_data = pd.DataFrame()


# Iterate over the file names
for file_name in listOfFileNames:
    # Construct the file path
    file_path = os.path.join(pathSpecified, file_name)
    # Read the file into a DataFrame
    # Define the skiprows and column data types
    skiprows = 5
    dtype = {
        'Order Date': 'datetime64',
        'Item Code': str,
        'POReference': str,
        'Supplier Id' : str,
        
        
    }

    # Load the Excel file
    data = pd.read_excel(file_path, index_col=False, skiprows=range(0, 5), dtype=dtype).iloc[0:].reset_index(drop=True)
    combined_data = combined_data.append(data)
# Display the loaded data
combined_data.head(4)
# Out:
# Following is the list of names of all the files present in the specified directory:
# ['01 JanJun18.xlsx', '02 JulDec18.xlsx', '03 JanJun19.xlsx', '04 JulDec19.xlsx', '05 JanJun20.xlsx', '06 JulDec20.xlsx', '07 Jan21Jun21.xlsx', '08 JulDec21.xlsx', '09 JanJun22.xlsx', '10 JulDec22.xlsx', '11 JanMay23.xlsx', '12 June23.xlsx', '13 July23.xlsx']
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
# C:\Users\shaikh.kamran\AppData\Local\Temp\ipykernel_16884\4277437666.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data)
#    Unnamed: 0              Business  Column1 Supplier Id  \
# 0         NaN  ACI Agrolink Limited      NaN    01180207
# 1         NaN  ACI Agrolink Limited      NaN    01180207
# 2         NaN  ACI Agrolink Limited      NaN    01180159
# 3         NaN  ACI Agrolink Limited      NaN    01180266
#
#                                Supplier Name  Column2  Column3   Country  \
# 0  Nantong Worldbase Imp. and Exp. Co., Ltd.      NaN      NaN     China
# 1  Nantong Worldbase Imp. and Exp. Co., Ltd.      NaN      NaN     China
# 2       Anritsu Infivis (Thailand) Co., Ltd.      NaN      NaN  Thailand
# 3             Neptune Refrigeration Co P Ltd      NaN      NaN     India
#
#    Column4 Currency       POReference  Column5 Order Date Order Type Category  \
# 0      NaN      USD  0000168918010541      NaN 2018-02-26     Import       CM
# 1      NaN      USD  0000168918010541      NaN 2018-02-26     Import       CM
# 2      NaN      USD  0000168918010628      NaN 2018-03-07     Import       CM
# 3      NaN      USD  0000168918010653      NaN 2018-03-08     Import       CM
#
#     Item Code              Item Name   Unit  POQuantity   PORate   Amount  \
# 0  5000011988  Contact Plate Freezer  1 Set         1.0  19000.0  19000.0
# 1  5000011987      Flake Ice Machine  1 Set         1.0  50000.0  50000.0
# 2  5000011401         Metal Detector    Set         1.0  14000.0  14000.0
# 3  5000012370             Compressor  1 Set         1.0  12900.0  12900.0
#
#    Advance        Create By         Create Date
# 0      0.0  Md. Nurul Hasan 2018-02-20 10:15:49
# 1      0.0  Md. Nurul Hasan 2018-02-20 10:15:24
# 2      0.0  Md. Nurul Hasan 2018-02-01 13:35:49
# 3      0.0  Md. Nurul Hasan 2018-03-05 13:12:03

# %%
# business_to_keep = ['ACI Animal Genetics',
# 'ACI Consumer Electronics',
# 'ACI Crop Care (ACI Formulations Limited)',
# 'ACI Flour',
# 'ACI Foods Ltd.',
# 'ACI Premio Plastics',
# 'Aerosol',
# 'Animal Health',
# 'CB Core ', 
# 'Edible Oil',
# 'Fertilizer',
# 'Hygiene',
# 'Paint',
# 'Pharma',
# 'Premiaflex',
# 'ACI Salt',
# 'Electrical',
# 'Field Crops',
# 'Mosquito Coil',
# 'Rice',
# 'Vanish',
# 'Vegetables',
# 'Vegetables-EWS',
# ]

# # business_to_keep =['Hygiene']


# combined_data = combined_data[combined_data['Business'].isin(business_to_keep)]

# %%
combined_data['Year'] = combined_data['Order Date'].dt.year
combined_data['Month'] = combined_data['Order Date'].dt.month_name()

import pandas as pd

def calculate_wap(amount, quantity):
    if quantity != 0:
        wap = amount / quantity
        return wap
    else:
        return None

# Group by 'Item Code', 'Year', and 'Month', and calculate the WAP
grouped_data = combined_data.groupby(['Order Type','Business','Item Code','Currency', 'Year', 'Month']).apply(lambda x: calculate_wap(x['Amount'].sum(), x['POQuantity'].sum()))

# Reset the index and rename the column
grouped_data = grouped_data.reset_index().rename(columns={0: 'WAP_MOM'})

grouped_data['Day'] = 1



# Generate automatic column names
column_names = grouped_data['Year'].astype(str) + '-' + grouped_data['Month'].astype(str) + '-' + grouped_data['Day'].astype(str)

pivot_df = grouped_data.pivot_table(index=['Business', 'Item Code','Currency'], columns=column_names, values='WAP_MOM', aggfunc=lambda x: x).reset_index()


# Define the desired column order
desired_order = ['Business', 'Item Code', 'Currency']

# Extract date columns and sort them in chronological order
date_columns = sorted([col for col in pivot_df.columns if '-' in col], key=lambda x: pd.to_datetime(x, format='%Y-%B-%d'))

# Concatenate the desired order with the sorted date columns
desired_order += date_columns

# Reindex the DataFrame columns
pivot_df = pivot_df.reindex(columns=desired_order)

display(pivot_df.head(5))
# Out:
#                Business   Item Code Currency 2018-January-1 2018-February-1  \
# 0  ACI Agrolink Limited  0701000061      USD            NaN             NaN
# 1  ACI Agrolink Limited  0701000082      USD            NaN             NaN
# 2  ACI Agrolink Limited     1000-01      BDT            NaN             NaN
# 3  ACI Agrolink Limited  1203000022      BDT            NaN             NaN
# 4  ACI Agrolink Limited  1203000051      BDT            NaN             NaN
#
#   2018-March-1 2018-April-1 2018-May-1 2018-June-1 2018-July-1 2018-August-1  \
# 0          NaN          NaN        NaN         NaN         NaN           NaN
# 1          NaN          NaN        NaN         NaN         NaN           NaN
# 2          NaN          NaN        NaN         NaN         NaN           NaN
# 3          NaN          NaN        NaN         NaN         NaN           NaN
# 4      19000.0          NaN        NaN         NaN         NaN           NaN
#
#   2018-September-1 2018-October-1 2018-November-1 2018-December-1  \
# 0              NaN            NaN             NaN             NaN
# 1              NaN            NaN             NaN             NaN
# 2              NaN            NaN             NaN           205.0
# 3              NaN            NaN             NaN             NaN
# 4              NaN            NaN             NaN             NaN
#
#   2019-January-1 2019-February-1 2019-March-1 2019-April-1 2019-May-1  \
# 0            NaN             NaN          NaN          NaN        NaN
# 1            NaN             NaN          NaN          NaN        NaN
# 2            NaN             NaN          NaN          NaN        NaN
# 3            NaN             NaN          NaN          NaN        NaN
# 4            NaN             NaN          NaN          NaN        NaN
#
#   2019-June-1 2019-July-1 2019-August-1 2019-September-1 2019-October-1  \
# 0         NaN         NaN           NaN              NaN            NaN
# 1         NaN         NaN           NaN              NaN            NaN
# 2         NaN         NaN           NaN              NaN            NaN
# 3         NaN         NaN           NaN              NaN            NaN
# 4         NaN         NaN           NaN              NaN            NaN
#
#   2019-November-1 2019-December-1 2020-January-1 2020-February-1 2020-March-1  \
# 0             NaN             NaN            NaN             NaN          NaN
# 1             NaN             NaN            NaN             NaN          NaN
# 2             NaN             NaN            NaN             NaN          NaN
# 3             NaN             NaN            NaN             NaN          NaN
# 4             NaN             NaN            NaN             NaN          NaN
#
#   2020-April-1 2020-May-1 2020-June-1 2020-July-1 2020-August-1  \
# 0          NaN        NaN         NaN         NaN           NaN
# 1          NaN        NaN         NaN         NaN           NaN
# 2          NaN        NaN         NaN         NaN           NaN
# 3          NaN        NaN         NaN         NaN           NaN
# 4          NaN        NaN         NaN         NaN           NaN
#
#   2020-September-1 2020-October-1 2020-November-1 2020-December-1  \
# 0              NaN            NaN             NaN             NaN
# 1              NaN            NaN             NaN             NaN
# 2              NaN            NaN             NaN             NaN
# 3              NaN            NaN             NaN             NaN
# 4              NaN            NaN             NaN             NaN
#
#   2021-January-1 2021-February-1 2021-March-1 2021-April-1 2021-May-1  \
# 0            NaN             NaN          NaN          NaN        NaN
# 1            NaN             NaN          NaN          NaN        NaN
# 2            NaN             NaN          NaN          NaN        NaN
# 3            NaN             NaN          NaN          NaN        NaN
# 4            NaN             NaN          NaN          NaN        NaN
#
#   2021-June-1 2021-July-1 2021-August-1 2021-September-1 2021-October-1  \
# 0         NaN         NaN          2.79              NaN            NaN
# 1         NaN         NaN           NaN              NaN            NaN
# 2         NaN         NaN           NaN              NaN            NaN
# 3         NaN         NaN           NaN              NaN            NaN
# 4         NaN         NaN           NaN              NaN            NaN
#
#   2021-November-1 2021-December-1 2022-January-1 2022-February-1 2022-March-1  \
# 0             NaN             NaN            NaN             NaN          NaN
# 1             NaN            11.5            NaN             NaN          NaN
# 2             NaN             NaN            NaN             NaN          NaN
# 3             NaN             NaN            NaN             NaN          NaN
# 4             NaN             NaN            NaN             NaN          NaN
#
#   2022-April-1 2022-May-1 2022-June-1 2022-July-1 2022-August-1  \
# 0          NaN        NaN        3.02         NaN           2.7
# 1          NaN        NaN         NaN         NaN           NaN
# 2          NaN        NaN         NaN         NaN           NaN
# 3       2210.0        NaN         NaN         NaN           NaN
# 4          NaN        NaN         NaN         NaN           NaN
#
#   2022-September-1 2022-October-1 2022-November-1 2022-December-1  \
# 0              NaN            NaN             NaN             NaN
# 1              NaN            NaN             NaN             NaN
# 2              NaN            NaN             NaN             NaN
# 3              NaN            NaN             NaN             NaN
# 4              NaN            NaN             NaN             NaN
#
#   2023-January-1 2023-February-1 2023-March-1 2023-April-1 2023-May-1  \
# 0           2.74             NaN          NaN          NaN        NaN
# 1            NaN             NaN          NaN          NaN        NaN
# 2            NaN             NaN          NaN          NaN        NaN
# 3            NaN             NaN          NaN          NaN        NaN
# 4            NaN             NaN          NaN          NaN        NaN
#
#   2023-June-1 2023-July-1
# 0         NaN        2.12
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
pivot_df.columns
# Out:
# Index(['Business', 'Item Code', 'Currency', '2018-January-1',
#        '2018-February-1', '2018-March-1', '2018-April-1', '2018-May-1',
#        '2018-June-1', '2018-July-1', '2018-August-1', '2018-September-1',
#        '2018-October-1', '2018-November-1', '2018-December-1',
#        '2019-January-1', '2019-February-1', '2019-March-1', '2019-April-1',
#        '2019-May-1', '2019-June-1', '2019-July-1', '2019-August-1',
#        '2019-September-1', '2019-October-1', '2019-November-1',
#        '2019-December-1', '2020-January-1', '2020-February-1', '2020-March-1',
#        '2020-April-1', '2020-May-1', '2020-June-1', '2020-July-1',
#        '2020-August-1', '2020-September-1', '2020-October-1',
#        '2020-November-1', '2020-December-1', '2021-January-1',
#        '2021-February-1', '2021-March-1', '2021-April-1', '2021-May-1',
#        '2021-June-1', '2021-July-1', '2021-August-1', '2021-September-1',
#        '2021-October-1', '2021-November-1', '2021-December-1',
#        '2022-January-1', '2022-February-1', '2022-March-1', '2022-April-1',
#        '2022-May-1', '2022-June-1', '2022-July-1', '2022-August-1',
#        '2022-September-1', '2022-October-1', '2022-November-1',
#        '2022-December-1', '2023-January-1', '2023-February-1', '2023-March-1',
#        '2023-April-1', '2023-May-1', '2023-June-1', '2023-July-1'],
#       dtype='object')

# %%
columns_to_keep_for_wap = ['Business', 'Item Code', 'Currency', '2022-January-1', '2022-February-1', '2022-March-1', '2022-April-1',
       '2022-May-1', '2022-June-1', '2022-July-1', '2022-August-1',
       '2022-September-1', '2022-October-1', '2022-November-1',
       '2022-December-1', '2023-January-1', '2023-February-1', '2023-March-1',
       '2023-April-1', '2023-May-1', '2023-June-1', '2023-July-1']

pivot_df_wap = pivot_df[columns_to_keep_for_wap]

pivot_df_wap.head(5)
# Out:
#                Business   Item Code Currency 2022-January-1 2022-February-1  \
# 0  ACI Agrolink Limited  0701000061      USD            NaN             NaN
# 1  ACI Agrolink Limited  0701000082      USD            NaN             NaN
# 2  ACI Agrolink Limited     1000-01      BDT            NaN             NaN
# 3  ACI Agrolink Limited  1203000022      BDT            NaN             NaN
# 4  ACI Agrolink Limited  1203000051      BDT            NaN             NaN
#
#   2022-March-1 2022-April-1 2022-May-1 2022-June-1 2022-July-1 2022-August-1  \
# 0          NaN          NaN        NaN        3.02         NaN           2.7
# 1          NaN          NaN        NaN         NaN         NaN           NaN
# 2          NaN          NaN        NaN         NaN         NaN           NaN
# 3          NaN       2210.0        NaN         NaN         NaN           NaN
# 4          NaN          NaN        NaN         NaN         NaN           NaN
#
#   2022-September-1 2022-October-1 2022-November-1 2022-December-1  \
# 0              NaN            NaN             NaN             NaN
# 1              NaN            NaN             NaN             NaN
# 2              NaN            NaN             NaN             NaN
# 3              NaN            NaN             NaN             NaN
# 4              NaN            NaN             NaN             NaN
#
#   2023-January-1 2023-February-1 2023-March-1 2023-April-1 2023-May-1  \
# 0           2.74             NaN          NaN          NaN        NaN
# 1            NaN             NaN          NaN          NaN        NaN
# 2            NaN             NaN          NaN          NaN        NaN
# 3            NaN             NaN          NaN          NaN        NaN
# 4            NaN             NaN          NaN          NaN        NaN
#
#   2023-June-1 2023-July-1
# 0         NaN        2.12
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %% [markdown]
# ### Analytics :002

# %%
# left outer join


high_variance_df_ANA2 = pd.merge(high_variance_df, pivot_df_wap, on=['Business', 'Item Code', 'Currency'], how='left')
display(high_variance_df_ANA2.head(5))
display(high_variance_df_ANA2.shape)
# Out:
#               Business Supplier Id  \
# 0  ACI Premio Plastics    01200277
# 1  ACI Premio Plastics    01200277
# 2  ACI Premio Plastics    01190029
# 3  ACI Premio Plastics    01190029
# 4  ACI Premio Plastics    01190029
#
#                                        Supplier Name Country Currency  \
# 0  Tai Zhou Source of Colour New Material Technol...   China      USD
# 1  Tai Zhou Source of Colour New Material Technol...   China      USD
# 2             Wenling city gaobao  industry co.,Ltd.   China      USD
# 3             Wenling city gaobao  industry co.,Ltd.   China      USD
# 4             Wenling city gaobao  industry co.,Ltd.   China      USD
#
#   POReference Order Date Order Type Category   Item Code  \
# 0  2307000565 2023-07-09     Import       PM  3102001287
# 1  2307000565 2023-07-09     Import       PM  3102001288
# 2  2307000564 2023-07-09     Import       PM  3102001811
# 3  2307000564 2023-07-09     Import       PM  3102001836
# 4  2307001825 2023-07-20     Import       PM  3102001811
#
#                                   Item Name   Unit  POQuantity  PORate  \
# 0     HSF Titanium  Almirah Big Right –Silk    Pcs      3000.0   0.233
# 1      HSF Titanium  Almirah Big Left- Silk    Pcs      3000.0   0.233
# 2  HSF For Almirah Black Bell Dra Small 2/1  Piece      1500.0   0.162
# 3                  HSF for Platinum WD Joba    PCS       600.0   0.850
# 4  HSF For Almirah Black Bell Dra Small 2/1  Piece      1000.0   0.188
#
#    Amount  Advance           Create By         Create Date    AVRate  \
# 0   699.0      0.0  Krishno Gopal Saha 2023-07-09 10:44:58  0.300333
# 1   699.0      0.0  Krishno Gopal Saha 2023-07-09 10:44:58  0.350500
# 2   243.0      0.0  Krishno Gopal Saha 2023-07-09 10:43:31  0.379000
# 3   510.0      0.0  Krishno Gopal Saha 2023-07-09 10:43:31  0.352000
# 4   188.0      0.0  Krishno Gopal Saha 2023-07-20 08:48:15  0.379000
#
#         WAP  June or Previous price  Last_Price  Difference  Variance_P  \
# 0  0.277222                 0.21604       0.300    0.023111    7.695154
# 1  0.314000                 0.28670       0.460    0.036500   10.413695
# 2  0.220909                     NaN       0.310    0.158091   41.712641
# 3  0.284500                     NaN       0.472    0.067500   19.176136
# 4  0.220909                     NaN       0.162    0.158091   41.712641
#
#   2022-January-1 2022-February-1 2022-March-1 2022-April-1 2022-May-1  \
# 0        0.21604             NaN          NaN          NaN        NaN
# 1       0.229773             NaN          NaN          NaN        NaN
# 2            NaN             NaN          NaN          NaN        NaN
# 3            NaN             NaN          NaN          NaN        NaN
# 4            NaN             NaN          NaN          NaN        NaN
#
#   2022-June-1 2022-July-1 2022-August-1 2022-September-1 2022-October-1  \
# 0         NaN         NaN        0.2281          0.14056            NaN
# 1         NaN         NaN        0.2272          0.14056            NaN
# 2         NaN         NaN           NaN          0.33135          0.508
# 3         NaN         NaN           NaN              NaN            NaN
# 4         NaN         NaN           NaN          0.33135          0.508
#
#   2022-November-1 2022-December-1 2023-January-1 2023-February-1 2023-March-1  \
# 0             NaN             NaN            NaN             NaN          NaN
# 1             NaN             NaN            NaN             NaN          NaN
# 2           0.269           0.189            NaN           0.148          NaN
# 3             NaN             NaN            NaN           0.232          NaN
# 4           0.269           0.189            NaN           0.148          NaN
#
#   2023-April-1 2023-May-1 2023-June-1 2023-July-1
# 0        0.241       0.36         0.3        0.25
# 1        0.241        NaN        0.46        0.25
# 2        0.148       0.91        0.31      0.1724
# 3          NaN        NaN       0.472        0.85
# 4        0.148       0.91        0.31      0.1724
# (45, 43)

# %% [markdown]
# ### Busienss Group
# * Make amount in Taka

# %%
df_report_2= df_report_.copy()
display(df_report_2['Business'].unique())
display(df_report_2.head())
# Out:
# array(['ACI Agrolink Limited', 'ACI Crop Care (ACI Formulations Limited)',
#        'ACI Flour', 'ACI Premio Plastics', 'Aerosol', 'Animal Health',
#        'CB Core ', 'Fertilizer', 'Hygiene', 'Paint', 'Pharma',
#        'Premiaflex', 'ACI Animal Genetics', 'ACI CO-RO',
#        'ACI Consumer Electronics', 'ACI Foods Ltd.', 'ACI Motors Limited',
#        'ACI Salt', 'Common (Support Function)', 'Edible Oil',
#        'Electrical', 'Field Crops', 'Rice', 'Vanish', 'Vegetables',
#        'Vegetables-EWS'], dtype=object)
#    Unnamed: 0                                  Business  Unnamed: 2  \
# 0         NaN                      ACI Agrolink Limited         NaN
# 1         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 2         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 3         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 4         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
#
#   Supplier Id                               Supplier Name  Unnamed: 5  \
# 0    01191150  Shandong Weifang Rainbow Chemical Co. Ltd.         NaN
# 1    01180791            Coromandel International Limited         NaN
# 2        NSCL                Ningbo Synagrochem Co., Ltd.         NaN
# 3    01160037             NINGBO SUNJOY BIOSCIENCE CO LTD         NaN
# 4          HC                        Huikwang Corporation         NaN
#
#    Unnamed: 6 Country  Unnamed: 8 Currency POReference  Unnamed: 11  \
# 0         NaN   China         NaN      USD  2307000770          NaN
# 1         NaN   India         NaN      USD  2307000286          NaN
# 2         NaN   China         NaN      USD  2307000287          NaN
# 3         NaN   China         NaN      USD  2307000285          NaN
# 4         NaN  Taiwan         NaN      USD  2307000306          NaN
#
#   Order Date Order Type Category   Item Code                      Item Name  \
# 0 2023-07-10     Import       RM  0701000061                  Prism 27.5 SC
# 1 2023-07-05     Import       RM  0701000088  Bondage 80 WP (Blue Mancozeb)
# 2 2023-07-05     Import       RM  0701000011        ACIPRID PLUS 95 SP BULK
# 3 2023-07-05     Import       RM  0701000021                Camamix 750 WP
# 4 2023-07-05     Import       RM     1002019                     Nuben Bulk
#
#   Unit  POQuantity  PORate    Amount  Advance             Create By  \
# 0  Ltr     48000.0    2.12  101760.0      0.0  Faisal Ahmed Tahasan
# 1   Kg     14000.0    2.70   37800.0      0.0  Faisal Ahmed Tahasan
# 2   KG      6000.0   19.40  116400.0      0.0  Faisal Ahmed Tahasan
# 3   Kg     25000.0    4.25  106250.0      0.0  Faisal Ahmed Tahasan
# 4   KG     30000.0    3.70  111000.0      0.0  Faisal Ahmed Tahasan
#
#           Create Date  AVRate   WAP  June or Previous price  Last_Price
# 0 2023-07-10 15:42:27    2.74  2.74                    3.02        2.74
# 1 2023-07-05 10:43:56     NaN   NaN                    3.90        3.90
# 2 2023-07-05 10:48:39     NaN   NaN                   25.50       25.50
# 3 2023-07-05 10:39:08     NaN   NaN                    5.30        5.30
# 4 2023-07-05 12:02:15     NaN   NaN                    4.80        4.80

# %%
# Function to map business values
def map_business(business):
    if business in ['ACI Flour', 'ACI Foods Ltd.', 'ACI Salt', 'Edible Oil']:
        return 'Foods,Flour,Salt& Edible Oils'
    elif business == 'ACI Consumer Electronics':
        return 'ACI Consumer Electronics'
    elif business == 'ACI Crop Care (ACI Formulations Limited)':
        return 'ACI Crop Care'
    elif business == 'ACI Premio Plastics':
        return 'ACI Premio Plastics'
    elif business == 'Animal Health':
        return 'Animal Health'
    elif business == 'CB Core ':
        return 'Consumer'
    elif business == 'Pharma':
        return 'Consumer'
    elif business == 'Electrical':
        return 'Electrical'
    elif business in ['Fertilizer', 'Field Crops', 'Vegetables', 'Vegetables-EWS']:
        return 'Fertilizer'
    elif business == 'Hygiene':
        return 'Hygiene'
    elif business == 'Paint':
        return 'Paint'
    elif business == 'ACI Animal Genetics':
        return 'ACI Animal Genetics'
    elif business == 'Premiaflex':
        return 'Premiaflex'
    elif business == 'Rice':
        return 'Rice'
    elif business in ['Aerosol', 'Vanish', 'Mortin']:
        return 'SCJ'
    else:
        return "Other"

# Apply the mapping function to the 'Business' column
df_report_2['Business Name'] = df_report_2['Business'].apply(map_business)

display(df_report_2.head())
display(df_report_2.columns)
# Out:
#    Unnamed: 0                                  Business  Unnamed: 2  \
# 0         NaN                      ACI Agrolink Limited         NaN
# 1         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 2         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 3         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
# 4         NaN  ACI Crop Care (ACI Formulations Limited)         NaN
#
#   Supplier Id                               Supplier Name  Unnamed: 5  \
# 0    01191150  Shandong Weifang Rainbow Chemical Co. Ltd.         NaN
# 1    01180791            Coromandel International Limited         NaN
# 2        NSCL                Ningbo Synagrochem Co., Ltd.         NaN
# 3    01160037             NINGBO SUNJOY BIOSCIENCE CO LTD         NaN
# 4          HC                        Huikwang Corporation         NaN
#
#    Unnamed: 6 Country  Unnamed: 8 Currency POReference  Unnamed: 11  \
# 0         NaN   China         NaN      USD  2307000770          NaN
# 1         NaN   India         NaN      USD  2307000286          NaN
# 2         NaN   China         NaN      USD  2307000287          NaN
# 3         NaN   China         NaN      USD  2307000285          NaN
# 4         NaN  Taiwan         NaN      USD  2307000306          NaN
#
#   Order Date Order Type Category   Item Code                      Item Name  \
# 0 2023-07-10     Import       RM  0701000061                  Prism 27.5 SC
# 1 2023-07-05     Import       RM  0701000088  Bondage 80 WP (Blue Mancozeb)
# 2 2023-07-05     Import       RM  0701000011        ACIPRID PLUS 95 SP BULK
# 3 2023-07-05     Import       RM  0701000021                Camamix 750 WP
# 4 2023-07-05     Import       RM     1002019                     Nuben Bulk
#
#   Unit  POQuantity  PORate    Amount  Advance             Create By  \
# 0  Ltr     48000.0    2.12  101760.0      0.0  Faisal Ahmed Tahasan
# 1   Kg     14000.0    2.70   37800.0      0.0  Faisal Ahmed Tahasan
# 2   KG      6000.0   19.40  116400.0      0.0  Faisal Ahmed Tahasan
# 3   Kg     25000.0    4.25  106250.0      0.0  Faisal Ahmed Tahasan
# 4   KG     30000.0    3.70  111000.0      0.0  Faisal Ahmed Tahasan
#
#           Create Date  AVRate   WAP  June or Previous price  Last_Price  \
# 0 2023-07-10 15:42:27    2.74  2.74                    3.02        2.74
# 1 2023-07-05 10:43:56     NaN   NaN                    3.90        3.90
# 2 2023-07-05 10:48:39     NaN   NaN                   25.50       25.50
# 3 2023-07-05 10:39:08     NaN   NaN                    5.30        5.30
# 4 2023-07-05 12:02:15     NaN   NaN                    4.80        4.80
#
#    Business Name
# 0          Other
# 1  ACI Crop Care
# 2  ACI Crop Care
# 3  ACI Crop Care
# 4  ACI Crop Care
# Index(['Unnamed: 0', 'Business', 'Unnamed: 2', 'Supplier Id', 'Supplier Name',
#        'Unnamed: 5', 'Unnamed: 6', 'Country', 'Unnamed: 8', 'Currency',
#        'POReference', 'Unnamed: 11', 'Order Date', 'Order Type', 'Category',
#        'Item Code', 'Item Name', 'Unit', 'POQuantity', 'PORate', 'Amount',
#        'Advance', 'Create By', 'Create Date', 'AVRate', 'WAP',
#        'June or Previous price', 'Last_Price', 'Business Name'],
#       dtype='object')

# %%
grouped = df_report_2.groupby(['Business', 'Business Name'])['Amount'].sum().reset_index()
display(grouped.sort_values(by='Business Name'))
# Out:
#                                     Business                  Business Name  \
# 1                        ACI Animal Genetics            ACI Animal Genetics
# 3                   ACI Consumer Electronics       ACI Consumer Electronics
# 4   ACI Crop Care (ACI Formulations Limited)                  ACI Crop Care
# 8                        ACI Premio Plastics            ACI Premio Plastics
# 11                             Animal Health                  Animal Health
# 12                                  CB Core                        Consumer
# 20                                    Pharma                       Consumer
# 15                                Electrical                     Electrical
# 17                               Field Crops                     Fertilizer
# 16                                Fertilizer                     Fertilizer
# 24                                Vegetables                     Fertilizer
# 25                            Vegetables-EWS                     Fertilizer
# 9                                   ACI Salt  Foods,Flour,Salt& Edible Oils
# 14                                Edible Oil  Foods,Flour,Salt& Edible Oils
# 6                             ACI Foods Ltd.  Foods,Flour,Salt& Edible Oils
# 5                                  ACI Flour  Foods,Flour,Salt& Edible Oils
# 18                                   Hygiene                        Hygiene
# 13                 Common (Support Function)                          Other
# 7                         ACI Motors Limited                          Other
# 2                                  ACI CO-RO                          Other
# 0                       ACI Agrolink Limited                          Other
# 19                                     Paint                          Paint
# 21                                Premiaflex                     Premiaflex
# 22                                      Rice                           Rice
# 23                                    Vanish                            SCJ
# 10                                   Aerosol                            SCJ
#
#           Amount
# 1   2.660339e+07
# 3   2.080000e+05
# 4   1.074534e+07
# 8   1.686905e+07
# 11  3.150461e+07
# 12  2.595366e+07
# 20  7.544950e+04
# 15  8.000000e+04
# 17  2.302900e+06
# 16  3.272268e+07
# 24  4.748000e+05
# 25  3.167944e+06
# 9   1.946350e+07
# 14  6.670100e+06
# 6   3.187449e+07
# 5   1.555148e+07
# 18  1.831452e+07
# 13  1.069398e+05
# 7   1.450000e+04
# 2   1.600000e+07
# 0   2.932547e+05
# 19  1.035574e+07
# 21  1.293869e+08
# 22  3.982280e+06
# 23  5.777000e+05
# 10  8.893135e+06

# %%
# Group the DataFrame by 'Business Name' and 'Localmp'
grouped = df_report_2.groupby(['Business Name', 'Order Type']).agg({
    'Amount': 'sum',
    'Savings WAP': lambda x: sum(1 for val in x if val >= 0),
    'Savings June': lambda x: sum(1 for val in x if val >= 0)
}).reset_index()

# Rename columns for clarity
grouped.rename(columns={
    'Savings WAP': 'Gain WAP',
    'Savings June': 'Gain June'
}, inplace=True)

# Add 'Loss WAP' and 'Loss June' columns
grouped['Loss WAP'] = grouped['Amount'] - grouped['Gain WAP']
grouped['Loss June'] = grouped['Amount'] - grouped['Gain June']

# Rearrange the columns
columns_order = ['Business Name', 'Localmp', 'Amount', 'Gain WAP', 'Loss WAP', 'Gain June', 'Loss June']
grouped = grouped[columns_order]

# Display the resulting table
print(grouped)

# %% [markdown]
# #### Output

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
# path = 
writer = pd.ExcelWriter(r'D:\Shaikh_Desktop_Mydoc\Desktop\Automation Projects\20230727_Savings_Report_Commercial\Output_file\6M_sav_3.xlsx', engine='xlsxwriter')


# Write the MonthlyData DataFrame to a worksheet.

df_report_.to_excel(writer, sheet_name='COM', index=False)
high_variance_df_ANA2.to_excel(writer, sheet_name='COM_ANA', index=False)



# Save the writer and close it.
writer.save()
writer.close()
